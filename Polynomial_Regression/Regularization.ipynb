# %% [markdown]
# ### 岭回归 Ridge Regression

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(alpha=1)

# %% [markdown]
# ### LASSO Regression
