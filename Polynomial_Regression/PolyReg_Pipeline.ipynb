# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.uniform(-3,3,size=100)
X = x.reshape(-1,1)
y = 0.5*x**2+x+2+np.random.normal(0,1,100)

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree=2)
poly.fit(X)
X2 = poly.transform(X)

# %%
X2.shape
# Out:
# (100, 3)

# %%
X2[:5,:]
# Out:
# array([[ 1.        , -0.40398523,  0.16320406],
#        [ 1.        ,  0.73355882,  0.53810854],
#        [ 1.        ,  0.67929414,  0.46144052],
#        [ 1.        ,  2.64359445,  6.98859162],
#        [ 1.        ,  0.3633202 ,  0.13200157]])

# %%
X[:5,:]
# Out:
# array([[-0.40398523],
#        [ 0.73355882],
#        [ 0.67929414],
#        [ 2.64359445],
#        [ 0.3633202 ]])

# %%
from sklearn.linear_model import LinearRegression

lin_reg2 = LinearRegression()
lin_reg2.fit(X2,y)
y_predict2 = lin_reg2.predict(X2)

# %%
plt.scatter(x,y)
plt.plot(np.sort(x),y_predict2[np.argsort(x)],color = 'r')
plt.show()

# %%
lin_reg2.coef_
# Out:
# array([0.        , 1.01492355, 0.45490264])

# %%
lin_reg2.intercept_
# Out:
# 2.1018731443900363

# %%
X = np.arange(1,11).reshape(-1,2)

# %%
X.shape
# Out:
# (5, 2)

# %%
poly = PolynomialFeatures(degree=2)
poly.fit(X)
X2 = poly.transform(X)

# %%
X2.shape
# Out:
# (5, 6)

# %%
X2
# Out:
# array([[  1.,   1.,   2.,   1.,   2.,   4.],
#        [  1.,   3.,   4.,   9.,  12.,  16.],
#        [  1.,   5.,   6.,  25.,  30.,  36.],
#        [  1.,   7.,   8.,  49.,  56.,  64.],
#        [  1.,   9.,  10.,  81.,  90., 100.]])

# %% [markdown]
# ### Pipeline

# %%
x = np.random.uniform(-3,3,size=100)
X = x.reshape(-1,1)
y = 0.5*x**2+x+2+np.random.normal(0,1,100)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

poly_reg = Pipeline([
    ("poly",PolynomialFeatures(degree=2)),
    ("std_scaler", StandardScaler()),
    ("lin_reg", LinearRegression())
])

# %%
poly_reg.fit(X,y)
y_predict = poly_reg.predict(X)

# %%
plt.scatter(x,y)
plt.plot(np.sort(x),y_predict[np.argsort(x)],color = 'r')
plt.show()
